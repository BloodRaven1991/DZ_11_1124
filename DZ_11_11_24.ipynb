# %% [markdown]
# Задание 1
# Написать программу «справочник».Создать два списка
# целых. Один список хранит идентификационные коды,
# второй — телефонные номера. Реализовать меню для
# пользователя:
# ■ Отсортировать по идентификационным кодам;
# ■ Отсортировать по номерам телефона;
# ■ Вывести список пользователей с кодами и телефонами;
# ■ Выход.

# %%
def display_users(ids, phones):
    print("\nСписок пользователей:")
    for id, phone in zip(ids, phones):
        print(f"ID: {id}, Телефон: {phone}")

def main():
    ids = [101, 103, 102, 105, 104]
    phones = ["123-4567", "789-0123", "456-7890", "234-5678", "345-6789"]
    
    while True:
        print("\nМеню:")
        print("1. Отсортировать по идентификационным кодам")
        print("2. Отсортировать по номерам телефона")
        print("3. Вывести список пользователей с кодами и телефонами")
        print("4. Выход")
        
        choice = input("Выберите действие (1-4): ")
        
        if choice == '1':
            combined = sorted(zip(ids, phones))
            ids, phones = zip(*combined)
            print("Список отсортирован по идентификационным кодам.")
        elif choice == '2':
            combined = sorted(zip(phones, ids))
            phones, ids = zip(*combined)
            print("Список отсортирован по номерам телефона.")
        elif choice == '3':
            display_users(ids, phones)
        elif choice == '4':
            print("Выход из программы.")
            break
        else:
            print("Некорректный выбор. Пожалуйста, выберите 1-4.")

if __name__ == "__main__":
    main()
# Out:
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
#
# Список пользователей:
# ID: 101, Телефон: 123-4567
# ID: 103, Телефон: 789-0123
# ID: 102, Телефон: 456-7890
# ID: 105, Телефон: 234-5678
# ID: 104, Телефон: 345-6789
#
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
# Список отсортирован по идентификационным кодам.
#
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
#
# Список пользователей:
# ID: 101, Телефон: 123-4567
# ID: 102, Телефон: 456-7890
# ID: 103, Телефон: 789-0123
# ID: 104, Телефон: 345-6789
# ID: 105, Телефон: 234-5678
#
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
# Список отсортирован по номерам телефона.
#
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
#
# Список пользователей:
# ID: 101, Телефон: 123-4567
# ID: 105, Телефон: 234-5678
# ID: 104, Телефон: 345-6789
# ID: 102, Телефон: 456-7890
# ID: 103, Телефон: 789-0123
#
# Меню:
# 1. Отсортировать по идентификационным кодам
# 2. Отсортировать по номерам телефона
# 3. Вывести список пользователей с кодами и телефонами
# 4. Выход
# Выход из программы.

# %% [markdown]
# Задание 2
# Написать программу «книги». Создать два списка
# годы выпуска. Реализовать меню для пользователя:
# ■ Отсортировать по названию книг;
# ■ Отсортировать по годам выпуска;
# ■ Вывести список книг с названиями и годами выпуска;
# ■ Выход;

# %%
def display_books(titles, years):
    print("\nСписок книг:")
    for title, year in zip(titles, years):
        print(f"Название: \"{title}\", Год выпуска: {year}")

def main():
    titles = ["Война и мир", "1984", "Убийство в Восточном экспрессе", "Гордость и предубеждение", "Мастер и Маргарита"]
    years = [1869, 1949, 1934, 1813, 1967]
    
    while True:
        print("\nМеню:")
        print("1. Отсортировать по названию книг")
        print("2. Отсортировать по годам выпуска")
        print("3. Вывести список книг с названиями и годами выпуска")
        print("4. Выход")
        
        choice = input("Выберите действие (1-4): ")
        
        if choice == '1':
            combined = sorted(zip(titles, years))
            titles, years = zip(*combined)
            print("Список отсортирован по названию книг.")
        elif choice == '2':
            combined = sorted(zip(years, titles))
            years, titles = zip(*combined)
            print("Список отсортирован по годам выпуска.")
        elif choice == '3':
            display_books(titles, years)
        elif choice == '4':
            print("Выход из программы.")
            break
        else:
            print("Некорректный выбор. Пожалуйста, выберите 1-4.")

if __name__ == "__main__":
    main()
# Out:
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
#
# Список книг:
# Название: "Война и мир", Год выпуска: 1869
# Название: "1984", Год выпуска: 1949
# Название: "Убийство в Восточном экспрессе", Год выпуска: 1934
# Название: "Гордость и предубеждение", Год выпуска: 1813
# Название: "Мастер и Маргарита", Год выпуска: 1967
#
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
# Список отсортирован по названию книг.
#
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
#
# Список книг:
# Название: "1984", Год выпуска: 1949
# Название: "Война и мир", Год выпуска: 1869
# Название: "Гордость и предубеждение", Год выпуска: 1813
# Название: "Мастер и Маргарита", Год выпуска: 1967
# Название: "Убийство в Восточном экспрессе", Год выпуска: 1934
#
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
# Список отсортирован по годам выпуска.
#
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
#
# Список книг:
# Название: "Гордость и предубеждение", Год выпуска: 1813
# Название: "Война и мир", Год выпуска: 1869
# Название: "Убийство в Восточном экспрессе", Год выпуска: 1934
# Название: "1984", Год выпуска: 1949
# Название: "Мастер и Маргарита", Год выпуска: 1967
#
# Меню:
# 1. Отсортировать по названию книг
# 2. Отсортировать по годам выпуска
# 3. Вывести список книг с названиями и годами выпуска
# 4. Выход
# Выход из программы.
